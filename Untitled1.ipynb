# %% [markdown]
# <a href="https://colab.research.google.com/github/omawate05/CHK-1772906039311-6269/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d408dafb-e39c-45e1-a9bb-e6f13ecc35e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d408dafb-e39c-45e1-a9bb-e6f13ecc35e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

dataset_folder = "dataset"
os.makedirs(dataset_folder, exist_ok=True)

print("Dataset folder created")
# Out:
# Dataset folder created

# %% [markdown]
# igit clone https:\\github.com/

# %%
import cv2
import os

video_path = "myface.mp4.mp4"
dataset_folder = "dataset"

cap = cv2.VideoCapture(video_path)

count = 0
frame_number = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    if frame_number % 10 == 0:   # save every 10th frame
        filename = os.path.join(dataset_folder, f"image_{count}.jpg")
        cv2.imwrite(filename, frame)
        count += 1

    frame_number += 1

cap.release()

print("Images extracted:", count)
# Out:
# Images extracted: 70

# %%
import cv2
import os

input_folder = "dataset"
output_folder = "faces"

os.makedirs(output_folder, exist_ok=True)

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

count = 0

for image_name in os.listdir(input_folder):

    img_path = os.path.join(input_folder, image_name)
    img = cv2.imread(img_path)

    if img is None:
        continue

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5
    )

    for (x, y, w, h) in faces:
        face = img[y:y+h, x:x+w]

        face_filename = os.path.join(output_folder, f"face_{count}.jpg")
        cv2.imwrite(face_filename, face)

        count += 1

print("Faces extracted:", count)
# Out:
# Faces extracted: 57

# %%
import os
print(len(os.listdir("faces")))
# Out:
# 57

# %% [markdown]
# Create Student Folder

# %%
import os

student_name = "om"
dataset_path = "dataset/" + student_name

os.makedirs(dataset_path, exist_ok=True)

print("Student folder created")
# Out:
# Student folder created

# %% [markdown]
# Detect Face and Save to Student Folder

# %%
import cv2
import os

input_folder = "dataset"
output_folder = "dataset/student1"

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

count = 0

for image_name in os.listdir(input_folder):

    img_path = os.path.join(input_folder, image_name)

    if not image_name.endswith(".jpg"):
        continue

    img = cv2.imread(img_path)

    if img is None:
        continue

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:

        face = img[y:y+h, x:x+w]

        filename = os.path.join(output_folder, f"{count}.jpg")

        cv2.imwrite(filename, face)

        count += 1

print("Total faces saved:", count)
# Out:
# Total faces saved: 57
